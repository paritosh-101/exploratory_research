# %%
import numpy as np

# %%
path = "s12_temp_folder"

# %%
data = np.load(path+"/S2_DATA.npy")

# %%
print(data)
# Out:
# [[[0.10616845 0.09519573 0.09252669 ... 0.1227758  0.12959668 0.14501779]
#   [0.10409253 0.10468565 0.10438909 ... 0.12188612 0.12633452 0.13819692]
#   [0.10972716 0.10498221 0.09875445 ... 0.17289442 0.15776987 0.15361803]
#   ...
#   [0.08985765 0.0732503  0.08303677 ... 0.15688019 0.11032028 0.10794781]
#   [0.06079478 0.05219454 0.06198102 ... 0.11032028 0.10112693 0.1168446 ]
#   [0.11654804 0.11269276 0.12099644 ... 0.10972716 0.12663108 0.136121  ]]
#
#  [[0.14620403 0.13582444 0.1316726  ... 0.16132859 0.15599051 0.16429419]
#   [0.14264531 0.14234875 0.13938316 ... 0.15243179 0.14768683 0.15836299]
#   [0.13819692 0.14323843 0.14145907 ... 0.18060498 0.16963227 0.17052195]
#   ...
#   [0.12900356 0.11803084 0.12307236 ... 0.18623962 0.15450771 0.15361803]
#   [0.10349941 0.09786477 0.10765125 ... 0.16992883 0.14590747 0.15065243]
#   [0.1376038  0.13790036 0.14472123 ... 0.16014235 0.15628707 0.15599051]]
#
# ...

# %%
print(data.shape)
print(data.dtype)
# Out:
# (4, 256, 256)
# float64

# %%
from matplotlib import pyplot as plt

image = data[0,:,:]
plt.imshow(image)

# %%
image2 = data[1,:,:]
plt.imshow(image2)

# %%
image3 = data[2,:,:]
plt.imshow(image3)

# %%
image4 = data[3,:,:]
plt.imshow(image4)

# %%
nimage=3;

final = image/nimage + image2/nimage + image3/nimage

# %%
plt.imshow(final)

# %%
# rgb = np.zeros(image.shape[0], image.shape[1], 3)
rgb = np.dstack([image, image2, image3])

# %%
plt.imshow(rgb)

# %%
new1 = np.dstack([image2, image3, image4])
plt.imshow(new1)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
new2 = np.dstack([image, image2, image3, image4])
plt.imshow(new2)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
from os import listdir
from numpy import asarray
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
# Out:
# Using TensorFlow backend.

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import random

# %%
sample1 = load_img("munich/ROIs2017_winter/s1_0/ROIs2017_winter_s1_0_p1.png")
sample2 = load_img("munich/ROIs2017_winter/s2_0/ROIs2017_winter_s2_0_p1.png")

# %%
plt.imshow(sample1)

# %%
plt.imshow(sample2)

# %%
base_path = "munich/ROIs2017_winter/"

files = listdir(base_path + "s1/")
print(files)
files_len = len(files)
print(files_len)
rint1 = random.randint(0, files_len)
print(rint1)
lvl1 = files[rint1]
print(lvl1)
files = listdir(base_path + "s1/" + lvl1 + '/')
# print(files)
files_len = len(files)
print(files_len)
rint2 = random.randint(0, files_len)
print(rint2)
lvl2 = files[rint2]
print(lvl2)
# Out:
# ['s1_0', 's1_10', 's1_100', 's1_101', 's1_102', 's1_105', 's1_107', 's1_111', 's1_112', 's1_117', 's1_12', 's1_126', 's1_128', 's1_13', 's1_130', 's1_133', 's1_134', 's1_140', 's1_146', 's1_16', 's1_17', 's1_19', 's1_2', 's1_22', 's1_23', 's1_24', 's1_27', 's1_28', 's1_29', 's1_3', 's1_30', 's1_33', 's1_34', 's1_35', 's1_36', 's1_37', 's1_4', 's1_41', 's1_45', 's1_46', 's1_47', 's1_51', 's1_53', 's1_54', 's1_56', 's1_58', 's1_6', 's1_63', 's1_66', 's1_67', 's1_69', 's1_77', 's1_78', 's1_8', 's1_84', 's1_85', 's1_9', 's1_90', 's1_93', 's1_94', 's1_97']
# 61
# 5
# s1_105
# 900
# 761
# ROIs2017_winter_s1_105_p785.png

# %%
temp1 = lvl1.replace('s1', 's2')
temp2 = lvl2.replace('s1', 's2')
print(temp1)
print(temp2)
s2_path = base_path + 's2/' + temp1 + '/' + temp2
print(s2_path)
# Out:
# s2_105
# ROIs2017_winter_s2_105_p785.png
# munich/ROIs2017_winter/s2/s2_105/ROIs2017_winter_s2_105_p785.png

# %%
test = load_img(s2_path)
plt.imshow(test)

# %%
import numpy as np
base_path = "munich/ROIs2017_winter/"

files = listdir(base_path + "s1/")
print(files)
files_len = len(files)
print(files_len)
rint1 = np.random.randint(0, files_len)
print(rint1)
lvl1 = files[rint1]
print(lvl1)
s1_path = base_path + "s1/" + lvl1 + '/'
files = listdir(s1_path)
# print(files)
files_len = len(files)
print(files_len)
rint2 = np.random.randint(0, files_len, 10)
print(rint2)
# lvl2 = files[rint2]
# print(lvl2)
# Out:
# ['s1_0', 's1_10', 's1_100', 's1_101', 's1_102', 's1_105', 's1_107', 's1_111', 's1_112', 's1_117', 's1_12', 's1_126', 's1_128', 's1_13', 's1_130', 's1_133', 's1_134', 's1_140', 's1_146', 's1_16', 's1_17', 's1_19', 's1_2', 's1_22', 's1_23', 's1_24', 's1_27', 's1_28', 's1_29', 's1_3', 's1_30', 's1_33', 's1_34', 's1_35', 's1_36', 's1_37', 's1_4', 's1_41', 's1_45', 's1_46', 's1_47', 's1_51', 's1_53', 's1_54', 's1_56', 's1_58', 's1_6', 's1_63', 's1_66', 's1_67', 's1_69', 's1_77', 's1_78', 's1_8', 's1_84', 's1_85', 's1_9', 's1_90', 's1_93', 's1_94', 's1_97']
# 61
# 39
# s1_46
# 1109
# [778 834 996 850 247 635 775 526 827 419]

# %%
files_arr = np.array(files)
# print(files)
lvl2 = files_arr[rint2]
print(lvl2)
# Out:
# ['ROIs2017_winter_s1_46_p700.png' 'ROIs2017_winter_s1_46_p751.png'
#  'ROIs2017_winter_s1_46_p898.png' 'ROIs2017_winter_s1_46_p766.png'
#  'ROIs2017_winter_s1_46_p222.png' 'ROIs2017_winter_s1_46_p572.png'
#  'ROIs2017_winter_s1_46_p699.png' 'ROIs2017_winter_s1_46_p474.png'
#  'ROIs2017_winter_s1_46_p745.png' 'ROIs2017_winter_s1_46_p378.png']

# %%
temp1 = lvl1.replace('s1', 's2')
lvl2 = lvl2.tolist()
temp2 = [sub.replace('s1', 's2') for sub in lvl2]
print(temp1)
print(temp2)
s2_path = base_path + 's2/' + temp1 + '/'
# print(s2_path)
# Out:
# s2_46
# ['ROIs2017_winter_s2_46_p700.png', 'ROIs2017_winter_s2_46_p751.png', 'ROIs2017_winter_s2_46_p898.png', 'ROIs2017_winter_s2_46_p766.png', 'ROIs2017_winter_s2_46_p222.png', 'ROIs2017_winter_s2_46_p572.png', 'ROIs2017_winter_s2_46_p699.png', 'ROIs2017_winter_s2_46_p474.png', 'ROIs2017_winter_s2_46_p745.png', 'ROIs2017_winter_s2_46_p378.png']

# %%
img_sar=[]
img_opt=[]
for i in range(10):
    img = load_img(s1_path + lvl2[i])
    img_sar.append(img)
    img = load_img(s2_path + temp2[i])
    img_opt.append(img)

# %%
from keras.preprocessing.image import img_to_array

temp = img_to_array(img_sar[3])
print(temp.shape)
plt.imshow(img_sar[3])
# Out:
# (256, 256, 3)

# %%
plt.imshow(img_opt[3])

# %%
from os import listdir
from numpy import asarray
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline
